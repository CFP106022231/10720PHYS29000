# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
im1 = mpimg.imread('1.JPG')
im2 = mpimg.imread('2.JPG')
im3 = mpimg.imread('3.JPG')
im4 = mpimg.imread('4.JPG')
im5 = mpimg.imread('5.JPG')
plt.imshow(im1)

# %%
plt.imshow(im2)

# %%
plt.imshow(im3)

# %%
plt.imshow(im4)

# %%
plt.imshow(im5)

# %%
b_im1=im1[:,:,2]
print(b_im)
print(b_im.shape)
# Out:
# [[ 19  19  19 ... 134 134 133]
#  [ 19  19  19 ... 134 134 134]
#  [ 19  19  20 ... 134 134 134]
#  ...
#  [189 189 189 ... 186 186 185]
#  [188 188 188 ... 185 185 185]
#  [188 188 188 ... 185 184 184]]
# (960, 720)

# %%
b_im2=im2[:,:,2]
b_im3=im3[:,:,2]
b_im4=im4[:,:,2]
b_im5=im5[:,:,2]
b_im=np.stack((b_im1,b_im2,b_im3,b_im4,b_im5))
print(b_im.shape)
print(b_im)
# Out:
# (5, 960, 720)
# [[[ 19  19  19 ... 134 134 133]
#   [ 19  19  19 ... 134 134 134]
#   [ 19  19  20 ... 134 134 134]
#   ...
#   [189 189 189 ... 186 186 185]
#   [188 188 188 ... 185 185 185]
#   [188 188 188 ... 185 184 184]]
#
#  [[ 17  17  17 ...  15   7  22]
#   [ 17  17  17 ...  14   7  19]
#   [ 17  17  17 ...  14   8  15]
#   ...
#   [174 175 175 ... 170 169 169]
#   [174 174 175 ... 170 170 169]
#   [174 174 175 ... 171 170 170]]
#
#  [[ 16  16  16 ... 122 120 118]
#   [ 16  16  16 ... 123 120 118]
#   [ 16  16  16 ... 123 120 118]
#   ...
#   [174 174 176 ... 172 172 172]
#   [174 174 176 ... 172 172 172]
#   [174 174 176 ... 172 172 172]]
#
#  [[ 17  17  17 ... 119 117 116]
#   [ 17  17  17 ... 120 118 117]
#   [ 17  17  17 ... 120 118 117]
#   ...
#   [176 176 176 ... 170 170 170]
#   [176 176 176 ... 170 170 170]
#   [175 176 176 ... 170 170 170]]
#
#  [[ 13  14  14 ... 118 119 120]
#   [ 14  14  14 ... 119 119 119]
#   [ 14  14  14 ... 120 119 117]
#   ...
# ...

# %%
print(np.mean(b_im))
b_ave=np.mean(b_im,axis=0)
plt.imshow(b_ave)
# Out:
# 125.44991840277778

# %%
print(np.median(b_im))
b_med=np.median(b_im,axis=0)
plt.imshow(b_med)
# Out:
# 173.0

# %%
im=np.stack((im1,im2,im3,im4,im5),axis=0)
print(im.shape)
im_avee=np.mean(im,axis=0)
print(im_avee.shape)
plt.imshow(im_avee.astype(np.uint8))
plt.axis("off")
plt.savefig("邊緣半透明錢包.JPG",bbox_inches='tight',pad_inches=0)
# Out:
# (5, 960, 720, 3)
# (960, 720, 3)

# %%
im=np.stack((im1,im2,im3,im4,im5),axis=0)
print(im.shape)
im_medd=np.median(im,axis=0)
print(im_medd.shape)
plt.imshow(im_medd.astype(np.uint8))
plt.axis("off")
plt.savefig("邊緣消失錢包.JPG",bbox_inches='tight',pad_inches=0)
# Out:
# (5, 960, 720, 3)
# (960, 720, 3)
